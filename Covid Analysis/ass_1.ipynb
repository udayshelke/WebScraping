# %% [markdown]
# Basic Data Analysis with pandas and matplotlib
#
# Required Data File
#
# The data is scraped from the website worldometer.com using the Python library BeautifulSoup. The data is stored in corona.csv data file.
#
# The code for this is in app.py. Please run that and obtain the output before proceeding further.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importing data set 'corona.csv' created using app.py

# %%
df = pd.read_csv('corona.csv',delimiter = ',',thousands = ',',encoding='ISO-8859-1')
df
# Out:
#                    Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0    \r\nNorth America\r\n    39072935    4567.0     876,200      357.0
# 1             \r\nAsia\r\n    45716026   18614.0     592,281      296.0
# 2    \r\nSouth America\r\n    26416486       NaN     718,992        NaN
# 3           \r\nEurope\r\n    45892771   28861.0   1,045,378     1135.0
# 4           \r\nAfrica\r\n     4708640       2.0     125,938        NaN
# ..                     ...         ...       ...         ...        ...
# 709                 Total:    45765621   97719.0   1,041,959     2499.0
# 710                 Total:     4699198    8877.0     125,704      304.0
# 711                 Total:       65146     789.0       1,218        9.0
# 712                 Total:         721       NaN          15        NaN
# 713                 Total:   161076905  750261.0   3,344,811    13883.0
#
#      TotalRecovered  NewRecovered  ActiveCases
# 0          31184620        2264.0      7012115
# 1          39819417       21864.0      5304328
# 2          23963543           NaN      1733951
# 3          41467758       61125.0      3379635
# 4           4243248           NaN       339454
# ..              ...           ...          ...
# 709        41249967      144849.0      3473695
# 710         4235490        7685.0       338004
# 711           61222         299.0         2706
# 712             706           NaN            0
# 713       139850047      812167.0     17882047
#
# [714 rows x 8 columns]

# %% [markdown]
# Removing duplicate rows

# %%
df[df.Country == 'India']
# Out:
#     Country  TotalCases  NewCases TotalDeaths  NewDeaths  TotalRecovered  \
# 9     India    24046809     689.0    262,350         NaN        20079599
# 248   India    24046120  343288.0    262,350      3999.0        20073367
# 486   India    23702832  362406.0    258,351      4126.0        19728436
#
#      NewRecovered  ActiveCases
# 9          6232.0      3704860
# 248      344931.0      3710403
# 486      351786.0      3716045

# %% [markdown]
# We can notice duplicates. Let's remove them!vvvvvvvvvvvvvvvv

# %%
df1 = df.drop_duplicates(subset = ['Country'])
df1.shape
# Out:
# (231, 8)

# %% [markdown]
# We can see that the new DataFrame, df1, has less rows than the original df. So, duplicate rows have been removed.

# %%
df.shape
# Out:
# (714, 8)

# %%
df1.head()
# Out:
#                  Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0  \r\nNorth America\r\n    39072935    4567.0     876,200      357.0
# 1           \r\nAsia\r\n    45716026   18614.0     592,281      296.0
# 2  \r\nSouth America\r\n    26416486       NaN     718,992        NaN
# 3         \r\nEurope\r\n    45892771   28861.0   1,045,378     1135.0
# 4         \r\nAfrica\r\n     4708640       2.0     125,938        NaN
#
#    TotalRecovered  NewRecovered  ActiveCases
# 0        31184620        2264.0      7012115
# 1        39819417       21864.0      5304328
# 2        23963543           NaN      1733951
# 3        41467758       61125.0      3379635
# 4         4243248           NaN       339454

# %%
df1.dtypes
# Out:
# Country            object
# TotalCases          int64
# NewCases          float64
# TotalDeaths        object
# NewDeaths         float64
# TotalRecovered      int64
# NewRecovered      float64
# ActiveCases         int64
# dtype: object

# %%
df1[df1.Country == 'India']
# Out:
#   Country  TotalCases  NewCases TotalDeaths  NewDeaths  TotalRecovered  \
# 9   India    24046809     689.0    262,350         NaN        20079599
#
#    NewRecovered  ActiveCases
# 9        6232.0      3704860

# %% [markdown]
# **Deleting unneeded rows**

# %%
df1 = df1.sort_values(['TotalCases'],ascending = False)

# %%
df1
# Out:
#                    Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 7                    World   161872986   52047.0   3,360,026     1788.0
# 3           \r\nEurope\r\n    45892771   28861.0   1,045,378     1135.0
# 1             \r\nAsia\r\n    45716026   18614.0     592,281      296.0
# 0    \r\nNorth America\r\n    39072935    4567.0     876,200      357.0
# 8                      USA    33626097       NaN    598,540         NaN
# ..                     ...         ...       ...         ...        ...
# 224                Vanuatu           4       NaN          1         NaN
# 225       Marshall Islands           4       NaN                    NaN
# 226                  Samoa           3       NaN                    NaN
# 227           Saint Helena           2       NaN                    NaN
# 228             Micronesia           1       NaN                    NaN
#
#      TotalRecovered  NewRecovered  ActiveCases
# 7         140740607       85241.0     17772353
# 3          41467758       61125.0      3379635
# 1          39819417       21864.0      5304328
# 0          31184620        2264.0      7012115
# 8          26667199           NaN      6360358
# ..              ...           ...          ...
# 224               3           NaN            0
# 225               4           NaN            0
# 226               2           NaN            1
# 227               2           NaN            0
# 228               1           NaN            0
#
# [230 rows x 8 columns]

# %% [markdown]
# Dropping the row 'Total', as it seems incorrect. Dropping it on the basis of its index 230

# %%
df1 = df1.drop(230)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\S\OneDrive - Northeastern University\Desktop\DABI\ass_1.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/S/OneDrive%20-%20Northeastern%20University/Desktop/DABI/ass_1.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> df1 = df1.drop(230)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: '[230] not found in axis'

# %%
df1.head()
# Out:
#                  Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 7                  World   161872986   52047.0   3,360,026     1788.0
# 3         \r\nEurope\r\n    45892771   28861.0   1,045,378     1135.0
# 1           \r\nAsia\r\n    45716026   18614.0     592,281      296.0
# 0  \r\nNorth America\r\n    39072935    4567.0     876,200      357.0
# 8                    USA    33626097       NaN    598,540         NaN
#
#    TotalRecovered  NewRecovered  ActiveCases
# 7       140740607       85241.0     17772353
# 3        41467758       61125.0      3379635
# 1        39819417       21864.0      5304328
# 0        31184620        2264.0      7012115
# 8        26667199           NaN      6360358

# %%
df1.head(10)
# Out:
#                   Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 7                   World   161872986   52047.0   3,360,026     1788.0
# 3          \r\nEurope\r\n    45892771   28861.0   1,045,378     1135.0
# 1            \r\nAsia\r\n    45716026   18614.0     592,281      296.0
# 0   \r\nNorth America\r\n    39072935    4567.0     876,200      357.0
# 8                     USA    33626097       NaN    598,540         NaN
# 2   \r\nSouth America\r\n    26416486       NaN     718,992        NaN
# 9                   India    24046809     689.0    262,350         NaN
# 10                 Brazil    15436827       NaN    430,596         NaN
# 11                 France     5841129       NaN    107,250         NaN
# 12                 Turkey     5083996       NaN     44,059         NaN
#
#     TotalRecovered  NewRecovered  ActiveCases
# 7        140740607       85241.0     17772353
# 3         41467758       61125.0      3379635
# 1         39819417       21864.0      5304328
# 0         31184620        2264.0      7012115
# 8         26667199           NaN      6360358
# 2         23963543           NaN      1733951
# 9         20079599        6232.0      3704860
# 10        13979329           NaN      1026902
# 11         4999079           NaN       734800
# 12         4856763           NaN       183174

# %% [markdown]
# Dropping the continents statistics as they aren't of much use...

# %%
df1 = df1.drop(index = [0,1,2,3,4,5,6])

# %%
df1.head()
# Out:
#    Country  TotalCases  NewCases TotalDeaths  NewDeaths  TotalRecovered  \
# 7    World   161872986   52047.0   3,360,026     1788.0       140740607
# 8      USA    33626097       NaN    598,540         NaN        26667199
# 9    India    24046809     689.0    262,350         NaN        20079599
# 10  Brazil    15436827       NaN    430,596         NaN        13979329
# 11  France     5841129       NaN    107,250         NaN         4999079
#
#     NewRecovered  ActiveCases
# 7        85241.0     17772353
# 8            NaN      6360358
# 9         6232.0      3704860
# 10           NaN      1026902
# 11           NaN       734800

# %% [markdown]
# After the deletion of rows, the index values need to be updated too. We do so in the next step

# %%
df1 = df1.reset_index(drop = True)

# %%
df1
# Out:
#               Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 0               World   161872986   52047.0   3,360,026     1788.0
# 1                 USA    33626097       NaN    598,540         NaN
# 2               India    24046809     689.0    262,350         NaN
# 3              Brazil    15436827       NaN    430,596         NaN
# 4              France     5841129       NaN    107,250         NaN
# ..                ...         ...       ...         ...        ...
# 218           Vanuatu           4       NaN          1         NaN
# 219  Marshall Islands           4       NaN                    NaN
# 220             Samoa           3       NaN                    NaN
# 221      Saint Helena           2       NaN                    NaN
# 222        Micronesia           1       NaN                    NaN
#
#      TotalRecovered  NewRecovered  ActiveCases
# 0         140740607       85241.0     17772353
# 1          26667199           NaN      6360358
# 2          20079599        6232.0      3704860
# 3          13979329           NaN      1026902
# 4           4999079           NaN       734800
# ..              ...           ...          ...
# 218               3           NaN            0
# 219               4           NaN            0
# 220               2           NaN            1
# 221               2           NaN            0
# 222               1           NaN            0
#
# [223 rows x 8 columns]

# %% [markdown]
# **Sorting on the basis of specific columns**

# %% [markdown]
# Let's find out the 10 regions with the least Total Cases till now

# %%
df2 = df1.sort_values(['TotalCases'],inplace = False)

# %%
df2.head(10)
# Out:
#                    Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 222             Micronesia           1       NaN                    NaN
# 221           Saint Helena           2       NaN                    NaN
# 220                  Samoa           3       NaN                    NaN
# 219       Marshall Islands           4       NaN                    NaN
# 218                Vanuatu           4       NaN          1         NaN
# 217             MS Zaandam           9       NaN          2         NaN
# 216         Western Sahara          10       NaN          1         NaN
# 215             Montserrat          20       NaN          1         NaN
# 214        Solomon Islands          20       NaN                    NaN
# 213  Saint Pierre Miquelon          25       NaN                    NaN
#
#      TotalRecovered  NewRecovered  ActiveCases
# 222               1           NaN            0
# 221               2           NaN            0
# 220               2           NaN            1
# 219               4           NaN            0
# 218               3           NaN            0
# 217               7           NaN            0
# 216               8           NaN            1
# 215              19           NaN            0
# 214              20           NaN            0
# 213              25           NaN            0

# %%
df2 = df2.reset_index(drop = True)

# %% [markdown]
# **Changing column datatype for further operations**

# %% [markdown]
# Now let's see which countries have the most number of deaths recorded.

# %%
df3 = df1.sort_values(['TotalDeaths'],ascending = False,inplace= False)

# %%
df3
# Out:
#            Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 160            CAR        6866       NaN         95         NaN
# 168      Gibraltar        4286       NaN         94         NaN
# 98         Finland       89532       NaN        930         NaN
# 120      Australia       29957       2.0        910         NaN
# 165     San Marino        5083       NaN         90         NaN
# ..             ...         ...       ...         ...        ...
# 209          Macao          49       NaN                    NaN
# 207       Anguilla         109       NaN                    NaN
# 206  New Caledonia         124       NaN                    NaN
# 203       Dominica         178       NaN                    NaN
# 222     Micronesia           1       NaN                    NaN
#
#      TotalRecovered  NewRecovered  ActiveCases
# 160            5112           NaN         1659
# 168            4189           NaN            3
# 98            46000           NaN        42602
# 120           28861           NaN          186
# 165            4968           NaN           25
# ..              ...           ...          ...
# 209              49           NaN            0
# 207              89           NaN           20
# 206              58           NaN           66
# 203             176           NaN            2
# 222               1           NaN            0
#
# [223 rows x 8 columns]

# %% [markdown]
# But here we see that the sorting isn't correct. This might have something to do with the datatype of the column 'TotalDeaths'.
# Let's check.

# %%
df3.dtypes
# Out:
# Country            object
# TotalCases          int64
# NewCases          float64
# TotalDeaths        object
# NewDeaths         float64
# TotalRecovered      int64
# NewRecovered      float64
# ActiveCases         int64
# dtype: object

# %% [markdown]
# We can see that the datatype of 'TotalDeaths' is 'object'. For sorting, it must be in numeric form - either float or int.
# Here the problem is due to the fact that commas are used as separators in the TotalDeath values. So we need to remove them.

# %%
df3["TotalDeaths"] = df3["TotalDeaths"].str.replace(",","")

# %%
df3
# Out:
#            Country  TotalCases  NewCases TotalDeaths  NewDeaths  \
# 160            CAR        6866       NaN         95         NaN
# 168      Gibraltar        4286       NaN         94         NaN
# 98         Finland       89532       NaN        930         NaN
# 120      Australia       29957       2.0        910         NaN
# 165     San Marino        5083       NaN         90         NaN
# ..             ...         ...       ...         ...        ...
# 209          Macao          49       NaN                    NaN
# 207       Anguilla         109       NaN                    NaN
# 206  New Caledonia         124       NaN                    NaN
# 203       Dominica         178       NaN                    NaN
# 222     Micronesia           1       NaN                    NaN
#
#      TotalRecovered  NewRecovered  ActiveCases
# 160            5112           NaN         1659
# 168            4189           NaN            3
# 98            46000           NaN        42602
# 120           28861           NaN          186
# 165            4968           NaN           25
# ..              ...           ...          ...
# 209              49           NaN            0
# 207              89           NaN           20
# 206              58           NaN           66
# 203             176           NaN            2
# 222               1           NaN            0
#
# [223 rows x 8 columns]

# %% [markdown]
# We can see some empty values for TotalDeaths in the bottom rows. For sorting, we need to replace them with NaN. So while conversion, we 'coerce' the function to replace any value ot cannot covert, to NaN.

# %%
df3["TotalDeaths"] = pd.to_numeric(df3["TotalDeaths"],errors='coerce')

# %%
df3 = df3.sort_values(['TotalDeaths'],ascending = False)

# %%
df3 = df3.reset_index(drop=True)

# %%
df3
# Out:
#            Country  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0            World   161872986   52047.0    3360026.0     1788.0
# 1              USA    33626097       NaN     598540.0        NaN
# 2           Brazil    15436827       NaN     430596.0        NaN
# 3            India    24046809     689.0     262350.0        NaN
# 4           Mexico     2375115    3632.0     219901.0      311.0
# ..             ...         ...       ...          ...        ...
# 218          Macao          49       NaN          NaN        NaN
# 219       Anguilla         109       NaN          NaN        NaN
# 220  New Caledonia         124       NaN          NaN        NaN
# 221       Dominica         178       NaN          NaN        NaN
# 222     Micronesia           1       NaN          NaN        NaN
#
#      TotalRecovered  NewRecovered  ActiveCases
# 0         140740607       85241.0     17772353
# 1          26667199           NaN      6360358
# 2          13979329           NaN      1026902
# 3          20079599        6232.0      3704860
# 4           1895483        2247.0       259731
# ..              ...           ...          ...
# 218              49           NaN            0
# 219              89           NaN           20
# 220              58           NaN           66
# 221             176           NaN            2
# 222               1           NaN            0
#
# [223 rows x 8 columns]

# %% [markdown]
# Now we can see that the sorting is correct. So let's find out the required values. Note that the row with the highest value for deaths recorded is World. It doesn't make much sense to include it in our comparison, as it is evident that it will always be the highest value. So we will print the 10 countries, starting from index 1. Also, we only want the country name and the total deaths recorded.

# %%
df3[['Country','TotalDeaths']].loc[1:10]
# Out:
#      Country  TotalDeaths
# 1        USA     598540.0
# 2     Brazil     430596.0
# 3      India     262350.0
# 4     Mexico     219901.0
# 5         UK     127651.0
# 6      Italy     123745.0
# 7     Russia     115116.0
# 8     France     107250.0
# 9    Germany      86276.0
# 10  Colombia      79760.0

# %% [markdown]
# **Data Visualisation using matplotlib**

# %% [markdown]
# Now let's look at some data visualisation. The matplotlib library allows us to plot data in various forms.
#
# Importing matplotlib for drawing plots

# %%
# %matplotlib inline

# %% [markdown]
# Without passing any parameters, the plot() takes the index as the x-axis, every other columns as y-axis, and the kind of graph as line-graph.

# %%
df1.plot()
# Out:
# <Axes: >

# %% [markdown]
# Here we are going to show the countries with the highest death toll(as found in df3), depicting the number of deaths on the y-axis in various graphical forms.

# %% [markdown]
# **Vertical Bar Graph**

# %%
df3.loc[1:10].plot(x='Country',y='TotalDeaths',kind = 'bar')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# **Horizontal Bar Graph**

# %%
df3.loc[1:10].plot(x='Country',y='TotalDeaths',kind = 'barh')
# Out:
# <Axes: ylabel='Country'>

# %% [markdown]
# **Pie Chart**
#
# The pie chart has a different format. Instead of x and y axis, we pass the desired value as y and give the corresponding labels in the 'labels' parameter.

# %%
labels = df3['Country'].loc[1:10]

# %%
df3.loc[1:10].plot(kind='pie',labels=labels,y='TotalDeaths')
# Out:
# <Axes: ylabel='TotalDeaths'>

# %% [markdown]
# ven though we get a pie chart, there are improvements to be made.
#
# The legend table is covering the pie chart, and is not needed.
# It would be nice to show the % value of each pie slice.
# The pie chart should be larger.
# To carry out these modifications, the code will look like this...

# %%
df3.loc[1:10].plot(kind='pie',labels=labels,y='TotalDeaths',legend=None,autopct='%.2f %%',radius = 2).set_ylabel('')
# Out:
# Text(0, 0.5, '')
